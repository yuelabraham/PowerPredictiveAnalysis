# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
import datetime

# %%
df = pd.read_csv('/Users/yuelabraham/Downloads/data2/wind.csv')
df.head()
# Out:
#           Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0  01 01 2018 00:00           380.047791          5.311336
# 1  01 01 2018 00:10           453.769196          5.672167
# 2  01 01 2018 00:20           306.376587          5.216037
# 3  01 01 2018 00:30           419.645905          5.659674
# 4  01 01 2018 00:40           380.650696          5.577941
#
#    Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                     416.328908          259.994904
# 1                     519.917511          268.641113
# 2                     390.900016          272.564789
# 3                     516.127569          271.258087
# 4                     491.702972          265.674286

# %%
x = df.iloc[:, 2].values.reshape(-1, 1)
x
# Out:
# array([[5.31133604],
#        [5.67216682],
#        [5.2160368 ],
#        ...,
#        [8.43535805],
#        [9.42136574],
#        [9.97933197]])

# %%
y = df.iloc[:, 1].values
y
# Out:
# array([ 380.04779053,  453.76919556,  306.37658691, ..., 2201.10693359,
#        2515.6940918 , 2820.46606445])

# %%
plt.scatter(x, y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
y_test.shape
#x_test.shape
# Out:
# (10106,)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict([[5], [8], [11]])
# Out:
# array([ 582.80129546, 1433.67314584, 2284.54499623])

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 852.95198815, 1471.93918233, 1492.41596944, ...,  945.52881828,
#        2593.47659337, 2089.98738826])

# %%
error = y_pred - y_test
error
# Out:
# array([ 276.29500572, -147.36184306, -384.16508525, ...,  278.2717382 ,
#        -880.04635585, -253.07657658])

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color = 'black')

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8311144600393364
